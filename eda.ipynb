# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("UCI_HAR_Dataset/train/X_train.txt", header = None, delim_whitespace=True)

# %%
data
# Out:
#            0         1         2         3         4         5         6    \
# 0     0.288585 -0.020294 -0.132905 -0.995279 -0.983111 -0.913526 -0.995112
# 1     0.278419 -0.016411 -0.123520 -0.998245 -0.975300 -0.960322 -0.998807
# 2     0.279653 -0.019467 -0.113462 -0.995380 -0.967187 -0.978944 -0.996520
# 3     0.279174 -0.026201 -0.123283 -0.996091 -0.983403 -0.990675 -0.997099
# 4     0.276629 -0.016570 -0.115362 -0.998139 -0.980817 -0.990482 -0.998321
# 5     0.277199 -0.010098 -0.105137 -0.997335 -0.990487 -0.995420 -0.997627
# 6     0.279454 -0.019641 -0.110022 -0.996921 -0.967186 -0.983118 -0.997003
# 7     0.277432 -0.030488 -0.125360 -0.996559 -0.966728 -0.981585 -0.996485
# 8     0.277293 -0.021751 -0.120751 -0.997328 -0.961245 -0.983672 -0.997596
# 9     0.280586 -0.009960 -0.106065 -0.994803 -0.972758 -0.986244 -0.995405
# 10    0.276880 -0.012722 -0.103438 -0.994815 -0.973077 -0.985357 -0.995509
# ...

# %%
plt.plot(data)
plt.ylabel('some numbers')
plt.show()

# %%
plt.plot(data[4])
plt.ylabel('some numbers')
plt.show()

# %%
x = data[4:10]
plt.plot(x)
plt.ylabel('some numbers')
plt.show()

# %%
x = data.iloc[:,7:10]
plt.plot(x)
plt.ylabel('some numbers')
plt.show()

# %%
df1 = pd.read_csv("UCI_HAR_Dataset/train/subject_train.txt",header = None)

# %%
df1.head()
# Out:
#    0
# 0  1
# 1  1
# 2  1
# 3  1
# 4  1

# %%
df2 = pd.read_csv("UCI_HAR_Dataset/train/Y_train.txt",header = None)

# %%
df2.head()
# Out:
#    0
# 0  5
# 1  5
# 2  5
# 3  5
# 4  5

# %%
result=pd.concat([df1, df2], axis=1)
result.head()
# Out:
#    0  0
# 0  1  5
# 1  1  5
# 2  1  5
# 3  1  5
# 4  1  5

# %%
plt.plot(result)
plt.ylabel('some numbers')
plt.show()

# %%
x = result.iloc[:,0]
x.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: 0, dtype: int64

# %%
y = result.iloc[:,1]
y.head()
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# 4    5
# Name: 0, dtype: int64

# %%
plt.plot(y)
plt.ylabel("actions")
plt.xlabel("subjects")
plt.show()

# %%
output = []
for x in df1[0]:
    if x not in output:
        output.append(x)
print(output)
# Out:
# [1, 3, 5, 6, 7, 8, 11, 14, 15, 16, 17, 19, 21, 22, 23, 25, 26, 27, 28, 29, 30]

# %%
print(df2)
# Out:
#       0
# 0     5
# 1     5
# 2     5
# 3     5
# 4     5
# 5     5
# 6     5
# 7     5
# 8     5
# 9     5
# 10    5
# 11    5
# 12    5
# 13    5
# 14    5
# 15    5
# 16    5
# 17    5
# 18    5
# 19    5
# 20    5
# 21    5
# 22    5
# 23    5
# 24    5
# 25    5
# 26    5
# 27    4
# 28    4
# 29    4
# ...  ..
# 7322  2
# 7323  2
# 7324  2
# 7325  2
# 7326  2
# 7327  2
# 7328  2
# 7329  2
# 7330  2
# 7331  2
# 7332  2
# 7333  2
# 7334  2
# 7335  2
# 7336  2
# 7337  2
# 7338  2
# 7339  2
# 7340  2
# 7341  2
# 7342  2
# 7343  2
# 7344  2
# 7345  2
# 7346  2
# 7347  2
# 7348  2
# 7349  2
# 7350  2
# 7351  2
#
# [7352 rows x 1 columns]

# %%
plt.plot(output,df2)
plt.ylabel('some numbers')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-15541bab5052> in <module>()
# ----> 1 plt.plot(output,df2)
#       2 plt.ylabel('some numbers')
#       3 plt.show()
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3238                       mplDeprecation)
#    3239     try:
# -> 3240         ret = ax.plot(*args, **kwargs)
#    3241     finally:
#    3242         ax._hold = washold
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1708                     warnings.warn(msg % (label_namer, func.__name__),
#    1709                                   RuntimeWarning, stacklevel=2)
# -> 1710             return func(ax, *args, **kwargs)
#    1711         pre_doc = inner.__doc__
#    1712         if pre_doc is None:
#
# ...

# %%
for x in df1:
    if df1.item() == x:
        print(len(i))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-21d937b87bf2> in <module>()
#       1 for x in df1:
# ----> 2     if df1.item() == x:
#       3         print(len(i))
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'item'
